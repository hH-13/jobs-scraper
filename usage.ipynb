# %% [markdown]
# ---
# title: Job Scraper for Indeed, built with Selenium.
# theme:
#   dark: superhero
#   # dark: cyborg
#   light: cerulean
# format:
#   html:
#     page-layout: full
# ---

# %% [markdown]
# This is an example usage of the job scraper with a database like DuckDB to persist scraped information for future use and analysis.\
# Source: [hh-13/jobs-scraper@Github](https://github.com/hH-13/jobs-scraper/)

# %%
#| include: false 

# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# %% [markdown]
# - Run the example script to load data into the database

# %%
# !poetry run python scraper_example.py 'in.indeed.com' -k 'software engineer' -l 'Remote' -r 4 -n 1 --sort_by_date
# Out:
# Saved to DB!

# %% [markdown]
# - Connect to the duckdb database. DuckDB provides APIs in various languages, as well as a CLI tool. We'll use python for this example.

# %%
import duckdb

con = duckdb.connect("jobs.db")

# %%
#| include: false 

import polars as pl

# %%
#| include: false 

options, jobs = (
    {
        "search_term": "data",
        "location": "Remote",
        "search_radius": 4,
        "num_pages": 3,
        "url": [
            "https://in.indeed.com/jobs?q=data&l=Remote&sort=date&start=0",
            "https://in.indeed.com/jobs?q=data&l=Remote&sort=date&start=10",
            "https://in.indeed.com/jobs?q=data&l=Remote&sort=date&start=20",
        ],
        "Date posted": ["Last 24 hours", "Last 3 days", "Last 7 days", "Last 14 days"],
        "Remote": ["Remote (596)", "Hybrid work (3)"],
        "Pay": [
            "₹ 37,500.00+/month (501)",
            "₹ 67,500.00+/month (398)",
            "₹ 85,000.00+/month (310)",
            "₹ 1,00,000.00+/month (211)",
            "₹ 1,28,333.34+/month (102)",
        ],
        "Job type": [
            "Full-time (427)",
            "Contract (76)",
            "Temporary (75)",
            "Part-time (37)",
            "Internship (11)",
            "Fresher (7)",
        ],
        "Location": ["Remote (596)"],
        "Company": [
            "Nagarro (47)",
            "MNJ Software (19)",
            "Marktine Technology Solutions Pvt. Ltd. (17)",
            "Uplers (16)",
            "Rackspace Technology (10)",
            "Syneos - Clinical and Corporate - Prod (10)",
        ],
        "Job Language": ["English (596)"],
    },
    [
        {
            "title": "Engagement & Data Specialist",
            "url": "https://in.indeed.com/rc/clk?jk=285390b95f5eb315&bb=ieAR1gQO9ngB2dZZAT6xG55jhL5vtZnCefV3rOBRqsyV3BUir1rO5pFwuu_K7gYvyR5iWEay6R2FI9HeZdRdDE2mM0RBo7pkgeODQD1ZwjJHE0oQz45kG3PJOAr1oIAA&xkcb=SoAa67M3AavTmWx80x0LbzkdCdPP&fccid=9b477bc92ee08db0&cmp=Capital-Mantra&ti=Engagement+Specialist&vjs=3",
        },
        {
            "title": "Digital Marketing Specialist",
            "url": "https://in.indeed.com/rc/clk?jk=e0e2529609a9102f&bb=ieAR1gQO9ngB2dZZAT6xG9doJtV_8N2fVbuNrCIlzFji2Y-WeK_Ti_kmU3MjuiZpk6wAu91rY_i5DiF6IAozSn2vU2rXc-kSPc_PCFdqTke-_jVfFfz98kD2BAFVHDig&xkcb=SoCu67M3AavTmWx80x0KbzkdCdPP&fccid=49c27b2e2061f3b1&cmp=IHDLab&ti=Digital+Marketer&vjs=3",
        },
        {
        },
        {
            "title": "Data QA Engineer",
            "url": "https://in.indeed.com/rc/clk?jk=810f4dbb4ebc75cf&bb=NBjS1ulIal3iSnriPE7zBzEy5Zm1o2GRUMFRlYhhEj49KFgBIxa5cxfHEZ_nE2Wf3lyJ_gD6d3ESMlVbXx_-L6C1SOE11Sn6ft3LminMj8K-5V9YNS9plgwzsE6z2jD5&xkcb=SoAv67M3AavTDsU7B50FbzkdCdPP&fccid=9b2b8770d24effb2&vjs=3",
        },
    ],
)

# %%
#| include: false 

detes = [
    "Engagement & Data Specialist\n============================\n\nMANAH WellnessRemote₹50,000 - ₹60,000 a monthJob details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹50,000 - ₹60,000 a month\n### Job type\n\n* Full-time\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\nExperience: 2+ years\n\n\nResponsibilities:\n\n\nMember Categorization and Profiling:\n\n\n* Categorise alliance members by clients, partners, psychology networks, sectors, and geographical locations.\n* Maintain a detailed list of potential members and profile these members.\n\n\nOnboarding:\n\n\n* Manage the onboarding process for new alliance members, including sending emails, special invitations, and providing access to online/offline products.\n\n\nEngagement:\n\n\n* Plan and execute engagement activities such as twice-monthly learning circles.\n* Facilitate learning opportunities, sharing of best practices, and celebration events.\n* Develop and implement an engagement strategy to keep members actively involved.\n* Create and update a visual map showcasing alliance members and their geographical locations.\n* Produce a 1-minute video presentation to play before every learning circle.\n* Develop visually appealing and engaging content for alliance members.\n* Create new and exciting initiatives based on data insights to keep the alliance fresh and relevant.\n* Ensure that all materials are up-to-date and aligned with alliance goals.\n\n\nData Collection and Analysis:\n\n\n* Collect and analyse data on potential and existing alliance members.\n* Track key metrics related to member engagement, onboarding, and participation in events.\n* Conduct market research to identify trends, opportunities, and potential challenges within the mental health and wellbeing sectors.\n* Provide insights to support strategic decision-making and alliance growth.\n\n\nReporting:\n\n\n* Produce regular reports on the status of the alliance, including member categorization, engagement metrics, and event participation.\n* Present findings and recommendations to the VP.\n\n\nVisual Content and Communication:\n\n\n* Focus on how the alliance is presented to the outside world.\n* Create visually appealing content that showcases the alliance's activities, members, and achievements.\n* Ensure all communications and presentations are visually engaging and professionally designed.\n* Develop marketing and promotional materials to enhance the alliance’s visibility and attractiveness.\n* Ensure communication, culture, and language sensitivity in all content to cater to an international audience.\n\n\nCross-Cultural Competence:\n\n\n* Demonstrate understanding and appreciation of different cultures.\n* Adapt content and communication to be culturally sensitive and relevant to an international audience.\n* Ensure language sensitivity in all visual and written materials.\n\n\nSkills:\n\n\n* Strong organisational and project management skills.\n* Excellent communication and interpersonal skills.\n* Experience with member engagement and community management.\n* Proficiency in creating presentations and visual content.\n* Ability to work collaboratively with cross-functional teams.\n* Proficiency in data analysis and market research tools.\n* Strong analytical and reporting skills.\n* Ability to provide actionable insights based on data.\n* Experience in tracking and reporting key performance indicators (KPIs).\n* Creative skills for developing visually appealing and engaging content.\n* Sensitivity to cultural and language differences, and ability to adapt content accordingly.\n* Cross-cultural communication skills.\n\n\nJob Type: Full-time\n\n\nPay: ₹50,000.00 - ₹60,000.00 per month\n\n\nApplication Question(s):\n\n\n* What is your current/Last in hand salary?\n\n\nExperience:\n\n\n* total work: 2 years (Preferred)\n\n\nWork Location: Remote\n\nApply nowsave-icon&nbsp;Report job",
    "Digital Marketing Specialist\n============================\n\nNeonWavesRemoteFrom ₹35,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* From ₹35,000 a month\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**Job Description:** A proactive and skilled Digital Marketing Specialist to join our team. This role involves strategizing, implementing, and optimizing digital marketing campaigns across various digital channels to promote our brand, products, and services. The ideal candidate will contribute to both creative ideas and data-driven strategies to enhance digital communication and drive business growth.\n\n\n**Key Responsibilities:**\n\n\n* **Campaign Development and Execution:** Design and implement comprehensive marketing campaigns to enhance brand presence and achieve marketing targets.\n* **SEO and SEM:** Optimize content for search engines and execute PPC campaigns to increase visibility and traffic.\n* **Content Management:** Create engaging content for diverse platforms and manage the distribution to ensure consistent and effective messaging.\n* **Analytics:** Monitor, analyze, and report on campaign performance using analytics tools; adjust strategies based on insights gained.\n* **Project Management:** Coordinate with different teams and manage timelines to ensure the timely and successful delivery of digital marketing initiatives.\n\n\n**Required Skills and Qualifications:**\n\n\n* Proven experience in digital marketing with a strong portfolio of successful campaigns.\n* In-depth knowledge of SEO, content marketing, and digital advertising (PPC, SEM).\n* Proficiency in using digital marketing tools and analytics platforms.\n* Excellent communication, organizational, and creative thinking skills.\n* Ability to work in a fast-paced and dynamic environment.\n\n\n**Education:**\n\n\n* Bachelor’s degree in Marketing, Communications, or a related field preferred.\n\n\n**Experience:**\n\n\n* At least 2 years of relevant experience in a digital marketing role.\n\n\nJob Type: Full-time\n\n\nPay: From ₹35,000.00 per month\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Monday to Friday\n\n\nSupplemental pay types:\n\n\n* Performance bonus\n* Quarterly bonus\n* Yearly bonus\n\n\nApplication Question(s):\n\n\n* Can you describe your experience with digital marketing platforms and software?\n\n\nExperience:\n\n\n* Wix: 2 years (Required)\n* Video editing tools: 1 year (Preferred)\n* SEO: 2 years (Required)\n* SEM: 2 years (Required)\n* Google Ad Manager: 2 years (Required)\n* Ahrefs , Moz, or SEMrush: 2 years (Required)\n\n\nWork Location: Remote\n\n\nApplication Deadline: 31/05/2024\n\nReport job",
    "Marketing Associate\n===================\n\nIndika AI Private LimitedRemote₹20,000 - ₹25,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹20,000 - ₹25,000 a month\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n**A. Job Summary:**\n\n\n* Job Title: Marketing Manager\n* Experience: 1 - 2 years of experience end-to-end marketing strategy and execution.\n* Job Type: Full-time\n\n\n**B. About us:** \n\n\nIndika AI is a global data solutions company providing end-to-end data solutions helping clients across industries to unlock the true innovation potential of data and accelerate data-driven innovation and AI implementation. We provide data collection and digitization, anonymization, dataset curation and labeling/ annotation as well as model testing and evaluation services.\n\n\nIndika is working with clients across Academia, Corporate, Government as well as AI startups to support development and training of state-of-the-art AI solutions.\n\n\n**C. About the Role:**\n\n\nAs a Marketing Manager will support the marketing team in various capacities, including content creation, SEO, digital marketing campaigns, and graphic design. The ideal candidate will have 1-2 years of experience in marketing, a keen eye for detail, and proficiency in marketing tools and techniques.\n\n\n**D. Key Responsibilities:**\n\n\n* **Content Creation:** Develop and write engaging content for blogs, social media, newsletters, and website; edit and proofread for accuracy.\n* **SEO:** Conduct keyword research, implement on-page and off-page SEO techniques, and analyze website performance using SEO tools.\n* **Digital Marketing:** Assist in planning and executing digital marketing campaigns across various channels; track and report on campaign performance.\n* **Graphic Design:** Create graphics for social media and marketing materials using Canva; ensure all designs align with branding guidelines.\n* **Collaboration and Support:** Work with the marketing team on strategy implementation, manage social media accounts, and support events and online presence.\n* **Email Marketing:** Assist in creating and managing email marketing campaigns, including content creation, list management, and performance analysis.\n* **Market Research:** Conduct research on industry trends, competitor activities, and customer preferences to inform marketing strategies and decisions.\n\n\n**E. Qualifications and Requirements:**\n\n\n* Bachelor’s degree in Marketing, Communications, Business, or a related field.\n* 1-2 years of experience in end-to-end marketing strategy and execution.\n* Proficiency in SEO tools (e.g., Google Analytics, SEMrush, Ahrefs).\n* Strong writing and editing skills with a keen eye for detail.\n* Experience with digital marketing platforms and tools.\n* Proficient in Canva for graphic design; knowledge of other design tools is a plus.\n* Excellent organizational and time-management skills.\n* Ability to work independently and as part of a team.\n* Creative thinking and problem-solving abilities.\n\n\nJob Type: Full-time\n\n\nPay: ₹20,000.00 - ₹25,000.00 per month\n\n\nSchedule:\n\n\n* Day shift\n\n\nApplication Question(s):\n\n\n* Do you have experience in working with B2B segments?\n\n\nExperience:\n\n\n* total work: 1 year (Preferred)\n\n\nWork Location: Remote\n\n\nExpected Start Date: 01/06/2024\n\nReport job",
    "Research Analyst (WFH Relevant candidates only, 0-2 year of experience)\n=======================================================================\n\nSnD ConfrereRemote₹8,000 - ₹12,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹8,000 - ₹12,000 a month\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Day shift\n* UK shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**About SnD Confrere**\n\n\nSnD Confrere is a team of the best associates and analysts diligently chasing the dream of becoming the world’s largest data research and advisory Company. We thrive on channelizing data from the remotest source and leveraging the power of data research and integration, to equip our global clients with real-time information for making informed decisions and attaining an edge over competition. We provide analytical solutions and frameworks, including Data Management Solutions, Event Sales Solutions, and Research & Advisory Solutions, to help our global clients accelerate enterprise-wide performance and drive the top line and bottom line of the organization.\n\n\n**Job Role**\n\n\n* Only Non-Technical People are required.\n* Contact Discovery\n* B2B Data collection through Web Based Research\n* Experience is Quality Check is Must\n* Organization and research skills\n* Strong written and verbal communication abilities.\n* Developing and maintaining the prospect database\n* Market research detailed in various tools like linkedin, Hoovers, Bloomberg and more.\n* Lead generation campaigns via telephone and email\n* Client reach-outs to international locations.\n* Demonstration and consultation meeting booking campaigns\n* Working with a high level of attention to detail\n* MS-Excel is Required and Advance Excel is Preferred for Database Management\n* Adding to efficiency is mandatory\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹8,000.00 - ₹12,000.00 per month\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Day shift\n* UK shift\n\n\nWork Location: Remote\n\nReport job",
    "Lead AI / ML / Data Science Engineer - India\n============================================\n\nFounding TeamsRemote₹63,43,673 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹63,43,673 a year\n### Job type\n\n* Part-time\n* Full-time\n### Shift and schedule\n\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Flexible schedule\n&nbsp;Full job description\n--------------------\n\n**Founding Teams** is a new AI Tech Incubator and talent platform. We are supporting the next generation of AI startup founders with the resources they need including engineering, product, sales, marketing, and operations staff to create and launch their products.\n\n\nThe ideal candidate will have a passion for next-generation AI tech startups and working with great global startup talent.\n\n\n**Job Title:** - Lead Engineer\n\n\n**Company**: Stealth AI Startup\n\n\n**Remote**: 16-20 hours per week.\n\n\n**Flexible hours :** Yes\n\n\n**Job Description**\n\n\n- Build prototype AI/ ML models and tools to help us understand our customers and create personalised customer recommendations across multiple use cases and productize solutions to scale\n\n\n- Deeply understand customers, their behaviours and pain points, and develop a diversity of AI models addressing an array of customers’ needs\n\n\n- Translate business needs into AI/ML problems and create innovative solutions to advance our business goals\n\n\n- Determine the types and amount of data needed and work with data engineer to identify data sources and ingest into data lake\n\n\n- Structure, standardise, and annotate data into processable formats for ML; enrich data with necessary attributes to allow sophisticated personalization\n\n\n- Help shape the way our data science team does work - researching and making key decisions about what we build, how we build it, and which tools are best for solving our problems\n\n\n- Work alongside software and data engineers to implement data processing and visualisation systems that make data readily available and simplify how insights are communicated\n\n\n- Evaluate the performance of AI models and make tradeoffs against quality metrics\n\n\nInvestigate, and resolve performance issues in a timely manner\n\n\n**Requirements**\n\n\n- Bachelor’s or Master’s degree in Mathematics, ML, statistics, Computer Science, Software/Data Engineering, or a related field\n\n\n- Strong mathematical background in probability, statistics, and optimization algorithms.\n\n\n- Experience in building machine learning models and deploying them to production to make real decisions, then measuring the impact of these decisions.\n\n\n- Deep understanding of and have applied various machine learning techniques for solving real-world problems.\n\n\n- Expertise with advanced programming skills in Python, Java or any of the major languages to build robust algorithms\n\n\n- Proficient with SQL and can work “full stack” to integrate solutions with our data ecosystem\n\n\n- Confident in taking ownership of projects from start to finish and enjoy the process of turning nebulous ideas into reality\n\n\n- Excellent communication skills\n\n\n- A self-starter who drives projects and builds strong relationships with stakeholders and teams to tackle large cross-functional efforts\n\n\n- Thrive with minimal guidance and process\n\n\n- Worked in both small teams/incubators and large corporations\n\n\nJob Types: Full-time, Part-time\n\n\nPay: ₹6,343,673.00 per year\n\n\nSchedule:\n\n\n* Monday to Friday\n\n\nWork Location: Remote\n\nReport job",
    "Machine Learning Validation Specialist\n======================================\n\nCodash SolutionsRemote₹1,20,000 - ₹1,30,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹1,20,000 - ₹1,30,000 a month\n### Job type\n\n* Part-time\n### Shift and schedule\n\n* Day shift\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Work from home\n&nbsp;Full job description\n--------------------\n\nJob Description –\n\n\nValidation/QA supporting supporting Data Scientists. The role is part part of Manufacturing\n\n\nIntelligence team in India and supporting colleagues across different geographies. Comes with flexibility to work remotely.\n\n\nResponsibilities:\n\n\nSupport team of data scientists as the machine learning models QA/validation SME\n\n\nResponsible for documenting the model Qualification Plan and Technical Specification documents in collaboration with the data scientists and project team.\n\n\nDocument business and technical requirements for the ML model, including accuracy, performance, and functionality.\n\n\nCreate, Review and approve test cases to ensure model requirements and performance criteria are met.\n\n\nWork closely with Data Scientists and Subject Matter Experts to ensure thorough evaluation and testing of the model.\n\n\nGenerate summary reports as per the Qualification Plan.\n\n\nInterpret test results and provide feedback for improvement.\n\n\nSkills Required:\n\n\nMust haves:\n\n\nExperience or familiarity with Computer System Validation/Quality Assurance practices in a Digital or IT organization\n\n\nFamiliarity with the lifecycle of AI/ML projects and Software Development.\n\n\nBasic understanding of statistical analysis and programming language e.g. Python\n\n\nExcellent documentation and writing skills\n\n\nExperience of using Document management Software\n\n\nGood to haves:\n\n\nExperience with AI/ML modeling, preferably in healthcare/life science data.\n\n\nHands on experience with programming languages such as Python, R.\n\n\nExperience in Pharmaceutical manufacturing processes or chemical engineering background highly preferred.\n\n\nJob Type: Part-time\n\n\nPay: ₹120,000.00 - ₹130,000.00 per month\n\n\nExpected hours: 30 per week\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Day shift\n* Monday to Friday\n\n\nExperience:\n\n\n* total work: 7 years (Required)\n* AI/ML: 5 years (Required)\n\n\nWork Location: Remote\n\nReport job",
    "Data Migration Specialist\n=========================\n\nBBC Global Services/SnapscaleRemote₹25,000.00 - ₹47,403.56 a monthJob details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹25,000.00 - ₹47,403.56 a month\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Night shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Health insurance\n* Internet reimbursement\n* Paid sick time\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**Data Migration Specialist**\n\n\n**Job Description:**\n\n\nAs a Data Migration Specialist, you will ensure the seamless transfer of data from the existing EMR system to the new EMR system. Your key responsibilities will include:\n\n\n**Key Responsibilities:**\n\n\n* Data Transfer and Accuracy:\n* Collection Amounts: Transfer copays, coinsurance, and deductibles.\n* Policy Notes: Migrate benefits verification information.\n* Case Updates:Update visit eligibility indicators and necessary documentation, and maintain an issues list for problem resolution.\n* Authorization Entry: Ensure the latest authorizations are entered, adding any issues to a tracking list.\n* Claims (Patient and Insurance): Transfer outstanding claims, including CPT codes, charges, adjustments, and balances.\n* Patient Information Management:\n* Guarantor Information: Transfer guarantor details for minors and patients with legal guardians.\n* ID/Insurance Cards: Upload scans of ID and insurance cards.\n* Intakes/Financials: Migrate intake forms and financial agreements.\n* Referrals/Scripts: Transfer the latest signed POCs and scripts.\n* Documentation and Schedule Audit::\n* Authorization/VOB Documents: Transfer and upload the latest authorization and benefits verification documents.\n* Schedule Audit: Verify and correct the schedule to ensure all visits are transferred.\n* Chat Notes: Enter front desk communication notes into the new EMR as case notes.\n* System Setup and Support:\n* Site Set Up:\\*\\* Assist in setting up the new EMR system to ensure it is fully operational.\n* EDI/ERA Enrollment Assistance: Support EDI and ERA enrollment for seamless integration.\n\n\n**Qualifications & Experiences:**\n\n\n* Minimum of a bachelor's degree.\n* Experience with EMR systems and data migration.\n* Strong attention to detail and problem-solving skills.\n* Proficiency with Google Sheets and data management tools.\n* Excellent communication skills for coordinating with team members.\n* Ability to adhere to strict deadlines.\n* Preference for candidates with a medical background.\n\n\nJoin our team to ensure a smooth and efficient transition to our new EMR system, enhancing our ability to provide top-quality care.\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹25,000.00 - ₹47,403.56 per month\n\n\nBenefits:\n\n\n* Health insurance\n* Internet reimbursement\n* Paid sick time\n* Work from home\n\n\nSchedule:\n\n\n* Night shift\n\n\nSupplemental pay types:\n\n\n* Yearly bonus\n\n\nExperience:\n\n\n* total work: 4 years (Required)\n* Data migration: 4 years (Required)\n* HIPAA: 4 years (Required)\n* VOB: 3 years (Required)\n* EMR systems: 4 years (Required)\n* USA DATA MANAGEMENT: 3 years (Required)\n\n\nLanguage:\n\n\n* Fluenly in American English (Required)\n\n\nWork Location: Remote\n\nApply nowsave-icon&nbsp;Report job",
    "Power BI Developer\n==================\n\nMindTrilogy IT Solutions Pvt. LtdRemote₹1,00,000 - ₹1,20,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹1,00,000 - ₹1,20,000 a month\n### Job type\n\n* Temporary\n* Freelance\n### Shift and schedule\n\n* Morning shift\n* Day shift\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\nShould have minimum 6-9 years’ experience in PowerBI.\n\n\nProficient using PowerBI along with Azure Analysis Services.\n\n\n6+ years' experience creating and maintaining MS PowerBI reports in the MS cloud environment.\n\n\nShould good experience in Azure Analysis Services.\n\n\nExperience creating Power BI dashboards.\n\n\nExperience with data Analysis.\n\n\nData Analytics background (in SQL).\n\n\nETL experience preferred.\n\n\nExtensive knowledge creating reports and transformations within Power BI.\n\n\nWorking with customers to understand their business needs and translate them into written requirements which can be understood by technical and non-technical audiences.\n\n\nBuilding compelling, interactive and actionable reporting on top of structured data models\n\n\nSupporting the full BI life-cycle from requirements analysis, through design & development and on into release and support/maintenance phases.\n\n\nMust be exposed to Onsite-Offshore delivery model and should be able to deliver as per Project plan.\n\n\nGood verbal/written communication skills is a must.\n\n\nJob Type: Freelance\n\n\nPay: ₹100,000.00 - ₹120,000.00 per month\n\n\nSchedule:\n\n\n* Day shift\n* Monday to Friday\n* Morning shift\n\n\nExperience:\n\n\n* total work: 6 years (Preferred)\n* Power BI: 6 years (Preferred)\n* ETL: 5 years (Preferred)\n* Azure: 5 years (Preferred)\n\n\nWork Location: Remote\n\nReport job",
    "Senior Workday Business Systems Analyst\n=======================================\n\nAmerican Chase LLPRemote₹80,000 - ₹90,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹80,000 - ₹90,000 a month\n### Job type\n\n* Part-time\n* Temporary\n* Freelance\n### Shift and schedule\n\n* Overnight shift\n* Night shift\n* US shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**Job Summary:**\n\n\nWe are seeking a highly motivated and experienced Senior Workday Business Systems Analyst to join our growing team. In this role, you will play a critical role in supporting the implementation, administration, and reporting of Workday financial modules for our health system. You will work closely with business teams, application vendors, and IT to ensure seamless system integration, enhancements, and issue resolution.\n\n\n**Responsibilities:**\n\n\n* Act as a Workday subject matter expert, translating complex technical concepts into clear and concise business terms.\n\n\n* Support ERP upgrade initiatives, considering user expectations, project goals, work effort, accountability, and deliverables.\n\n\n* Gather user requirements, develop critical reports within assigned workstreams (intercompany, non-patient A/R, endowments/gifts), and provide user guidance on functionalities.\n\n\n* Participate in ongoing reviews of system configuration and design options for the aforementioned workstreams.\n\n\n* Manage complex intercompany transactions within the Workday General Ledger module.\n\n\n* Develop custom reports for various financial modules (Procure to Pay, A/P, A/R, Business Assets, Endowments & Gifts, Financial Accounting, Non-sponsored AR, Banking & Settlements).\n\n\n* Conduct training sessions for finance teams on Workday functionalities.\n\n\n* Independently address issues and design decisions, ensuring clear communication and documentation of complex concepts and issues.\n\n\n* Act as a liaison between business teams, application vendors, and IT for system integration, enhancements, and issue resolution.\n\n\n**Qualifications:**\n\n\n* Bachelor's degree in Computer Science or a related field (preferred).\n\n\n* 8+ years of experience in financial systems analysis and configuration.\n\n\n* Proven expertise in Workday Financials (General Ledger, Accounts Payable, Accounts Receivable, Grant Management, Custom Integrations).\n\n\n* In-depth knowledge of SDLC (Systems Development Life Cycle) methodologies.\n\n\n* Experience with digital transformation initiatives.\n\n\n* Strong analytical skills with experience in developing reports and dashboards.\n\n\n* Excellent communication and interpersonal skills, with the ability to effectively translate technical concepts to a non-technical audience.\n\n\n* Proven ability to manage complex projects, meet deadlines, and prioritize tasks.\n\n\n* Experience in a healthcare setting (highly preferred).\n\n\n* Knowledge of current healthcare trends and clinical operations (a plus).\n\n\n* Experience with ERP system implementations (a plus).\n\n\nJob Types: Part-time, Freelance  \nContract length: 12 months\n\n\nPay: ₹80,000.00 - ₹90,000.00 per month\n\n\nExpected hours: 30 per week\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Night shift\n* US shift\n\n\nExperience:\n\n\n* total work: 8 years (Required)\n\n\nShift availability:\n\n\n* Night Shift (Required)\n* Overnight Shift (Required)\n\n\nWork Location: Remote\n\n\nApplication Deadline: 31/05/2024\n\nReport job",
    "Senior Data Engineer\n====================\n\nArche GroupRemote₹8,00,000 - ₹18,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹8,00,000 - ₹18,00,000 a year\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Night shift\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n**Senior Data Engineer**\n\n\nJoin our dynamic team as a Senior Data Engineer and play a crucial role in shaping the future of our data-driven organization.\n\n\n**Responsibilities:**\n\n\n* Design and develop scalable, fault-tolerant, and high-performance data pipelines to ingest, process, and store large volumes of structured and unstructured data.\n* Implement efficient data transformation and enrichment processes to ensure data quality and consistency.\n* Collaborate with cross-functional teams, including data analysts and business stakeholders, to understand their data requirements and translate them into technical solutions.\n* Optimize data warehouse and data lake architectures to improve query performance and enable self-service analytics.\n* Automate data monitoring and alerting processes to proactively identify and resolve issues.\n* Stay up-to-date with the latest data engineering technologies and best practices, and recommend improvements to our data infrastructure.\n\n\n**Requirements:**\n\n\n* Bachelor's or Master's degree in Computer Science, Data Science, or a related field.\n* Minimum 8 years of experience as a data engineer or in a similar role.\n* Proficient in designing and implementing data pipelines using tools like Apache Spark, Apache Airflow, or Kafka.\n* Expertise in data modeling, data warehousing, and building scalable data processing systems.\n* Strong programming skills in Python, Scala, or Java, and experience with SQL and NoSQL databases.\n* Familiarity with cloud-based data platforms, such as AWS, Google Cloud, or Azure.\n* Excellent problem-solving and analytical skills, with the ability to work independently and as part of a team.\n* Passion for staying up-to-date with the latest trends and technologies in the data engineering field.\n\n\nIf you're ready to take your data engineering skills to the next level and contribute to the success of our data-driven initiatives, we encourage you to apply for this exciting opportunity. Join our team and help us unlock the full potential of our data assets.\n\n\nJob Type: Full-time\n\n\nPay: ₹800,000.00 - ₹1,800,000.00 per year\n\n\nSchedule:\n\n\n* Night shift\n\n\nExperience:\n\n\n* Data Engineer: 8 years (Required)\n\n\nWork Location: Remote\n\nReport job",
    "Quant Content Developer Intern (GRE/GMAT)\n=========================================\n\nUforia Infotech SolutionsRemote₹4,000 - ₹5,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹4,000 - ₹5,000 a month\n### Job type\n\n* Part-time\n* Full-time\n### Shift and schedule\n\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Flexible schedule\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**Job Summary:**\n\n\nCareerGeek, a cutting-edge edu-tech startup, is seeking a dynamic and enthusiastic Quant Content Developer Intern to collaborate closely with the Head of the Quant Department. Our mission is to revolutionize GRE preparation, making it accessible and impactful for a diverse audience. This role offers an exciting opportunity to engage in extensive research and innovative content development under the guidance of industry experts.\n\n\n**Work Schedule:**\n\n\n· Flexible hours, approximately 2-4 hours per day\n\n\n· Up to 15-20 hours per week\n\n\n**Key Responsibilities:**\n\n\n· **Innovative Content Creation:**   \nConduct in-depth research and develop high-quality quantitative content aligned with the strategic vision set by the Head of the Quant Department.\n\n\n· **Precision Editing:**   \nRefine and polish content based on expert feedback to ensure accuracy and clarity.\n\n\n· **Video Production Support:**  \nAssist in the creation of handouts and deliverables for video tutorials and quant lecture series.\n\n\n· **Holistic Learning Experience:**  \nImmerse yourself in the comprehensive process of conceptualizing, operationalizing, and optimizing GRE quant preparation.\n\n\n· **Develop High-Quality GRE Quantitative Practice Questions**\n\n\nCreate diverse GRE quantitative practice questions with detailed explanations to enhance student learning.\n\n\n· **Review and Improve Existing GRE Quantitative Content**\n\n\nEvaluate and update current materials to ensure accuracy and clarity, aligning with the latest GRE standards.\n\n\n· **Assist in the Creation of Study Guides, Tips, and Strategies**\n\n\nCollaborate on developing study guides and providing tips and strategies for the quantitative section of the GRE.\n\n\n**Qualifications and Skills:**\n\n\n· **Quantitative Proficiency:**   \nStrong foundation in mathematics and quantitative reasoning.\n\n\n· **Educational Background:**  \nBachelor's degree in Mathematics, Engineering, Economics or a related field preferred. Candidates from other disciplines with strong quantitative skills and a passion for content development and teaching are encouraged to apply.\n\n\n· **Research Aptitude:**   \nKeen interest in conducting thorough research to produce accurate and insightful content.\n\n\n· **Technical Savvy:**  \nProficiency in creating engaging PowerPoint presentations and informative handouts.\n\n\n· **Exam Experience:**  \nShould have prepared for or taken the GRE, GMAT, or CAT exams.\n\n\n· **Skills and Attributes:**\n\n\nAttention to detail and a commitment to producing high-quality work.\n\n\nAbility to work independently and meet deadlines.\n\n\n**Benefits:**\n\n\n· **Expert Mentorship:**   \nGain invaluable insights and skills from direct mentorship by a reputed industry expert.\n\n\n· **Career Advancement:**   \nExplore opportunities for vertical and lateral growth within our innovative startup.\n\n\n· Networking Opportunities:  \nWork closely with serial entrepreneurs and expand your professional network under their guidance.\n\n\n**Experience:**\n\n\n· **Research-Oriented Mindset:**  \nIdeal candidates are proactive and resourceful, capable of utilizing tools like Google and ChatGPT to find high-quality answers.\n\n\n· **Freshers Welcome:**   \nNo prior experience required, though it is a bonus. Familiarity with the GRE exam, either as an aspirant or as faculty, is ideal.\n\n\n**Work Location:** Remote\n\n\n**Note:**  \nPrepare to engage deeply with the GRE exam and work under the direct tutelage of top-ranked professionals in the industry.\n\n\nJob Types: Full-time, Part-time\n\n\nPay: ₹4,000.00 - ₹5,000.00 per month\n\n\nExpected hours: 10 – 20 per week\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Day shift\n\n\nExperience:\n\n\n* total work: 1 year (Preferred)\n\n\nWork Location: Remote\n\n\nApplication Deadline: 28/05/2024\n\nReport job",
    "PostgreSQL Database Administrator (DBA)\n=======================================\n\nGradient Cyber LLCRemote₹10,00,000 - ₹18,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹10,00,000 - ₹18,00,000 a year\n### Job type\n\n* Full-time\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n\n**Overview:**\n\n\n We are seeking a skilled PostgreSQL Database Administrator (DBA) to manage and optimize our PostgreSQL database infrastructure. As a PostgreSQL DBA, you will be responsible for ensuring the performance, availability, and security of our databases. You will collaborate with our development, operations, and security teams to design and implement efficient database solutions that meet our business needs.\n\n\n\n **About Gradient Cyber:**\n\n\n Gradient Cyber is a leading player in the cyber security industry, dedicated to delivering innovative solutions that transform businesses. We focus on providing 24/7 protection with our Managed Extended Detection and Response (MXDR) services, specifically designed for the mid-market. Our customer-centric approach and innovative product roadmap set us apart in the industry. At Gradient Cyber, we are committed to fostering an environment that promotes individual growth and success. We recruit exceptional individuals who are eager to excel, contribute innovative ideas, and advance within a company brimming with possibilities. Join us and play a pivotal role in shaping the future of our product portfolio and customer experience.\n\n\n\n **Key Responsibilities:**\n\n\n* **Database Administration:** Manage, monitor, and maintain PostgreSQL database systems to ensure optimal performance, reliability, and security.\n* **Performance Tuning:** Proactively identify and address performance bottlenecks and optimize SQL queries and database configurations for improved efficiency.\n* **Backup and Recovery:** Develop and implement robust backup and recovery strategies to safeguard data integrity and minimize downtime in case of system failures.\n* **High Availability and Disaster Recovery:** Design, implement, and manage high availability (HA) and disaster recovery (DR) solutions, such as replication, clustering, and failover mechanisms.\n* **Security:** Implement and enforce security policies and access controls to protect sensitive data against unauthorized access, data breaches, and other security threats.\n* **Capacity Planning:** Monitor database growth trends and plan for future capacity requirements by scaling resources and infrastructure as needed.\n* **Automation and Scripting:** Develop automation scripts and tools to streamline database administration tasks, deployments, and maintenance processes.\n* **Database Upgrades and Patching:** Plan and execute database upgrades, patches, and migrations in coordination with the development and operations teams to ensure minimal disruption to business operations.\n* **Documentation:** Maintain comprehensive documentation of database configurations, procedures, and best practices for reference and knowledge sharing.\n* **Collaboration:** Work closely with developers, system administrators, and other stakeholders to troubleshoot database-related issues, provide technical guidance, and support application development and deployment efforts.\n\n\n**Requirements**\n\n\n* Bachelor’s degree in Computer Science, Information Technology, or a related field (or equivalent experience).\n* Proven experience as a PostgreSQL Database Administrator or similar role in a production environment.\n* In-depth knowledge of PostgreSQL architecture, configuration, performance tuning, and troubleshooting.\n* Proficiency in SQL and database query optimization techniques.\n* Experience with database backup and recovery solutions, including point-in-time recovery (PITR) and disaster recovery planning.\n* Familiarity with database security best practices and regulatory compliance requirements (e.g., GDPR, HIPAA).\n* Strong scripting skills (e.g., Bash, Python) for automation and task orchestration.\n* Experience with database migration, replication, clustering, and high availability solutions (e.g., PostgreSQL replication, Patroni, Pgpool-II).\n* Excellent communication and collaboration skills, with the ability to work effectively in a cross-functional team environment.\n\n\n**Preferred Qualifications:**\n\n\n* PostgreSQL certification (e.g., PostgreSQL Certified Administrator).\n* Experience with other database technologies (e.g., MySQL, Oracle, MongoDB).\n* Knowledge of cloud platforms and database services (e.g., AWS RDS, Google Cloud SQL, Azure Database for PostgreSQL).\n* Familiarity with DevOps practices and tools (e.g., Docker, Kubernetes, Terraform).\n Experience with performance monitoring and diagnostic tools (e.g., pg\\_stat\\_statements, pgBadger, pg\\_top). \n \n\n**Equal Opportunity Statement:**\n\n\n Gradient Cyber is an equal opportunity employer. We are committed to creating a diverse and inclusive workplace where all employees feel valued and respected. We encourage applications from individuals of all backgrounds and experiences.\n\n\nReport job",
    "Data Support Analyst(Fintech) (Remote)\n======================================\n\nNivodaRemoteYou must create an Indeed account before continuing to the company website to applyApply nowsave-icon&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Flexible schedule\n&nbsp;Full job description\n--------------------\n\n\n\n\n**About Nivoda**\n\n\n\n Nivoda is the industry leading B2B diamond and gemstones marketplace, connecting jewellery retailers to gemstone supplies, in order to save time and money whilst gaining access to a global diamond supply at the best prices, all with zero inventory risk.\n \n\n\n  \n With a team of over 400 dedicated employees around the world and a wealth of experience in the industry, Nivoda has developed an award-winning solution that enables jewellery businesses of any size, in any location, to buy and sell diamonds in the most profitable, efficient and hassle-free manner.\n \n\n\n  \n Over the course of the last six years, Nivoda has evolved into a global platform recognised for its innovation, customer service and ability to deliver a seamless, reliable and efficient experience.\n \n\n\n **Responsibilities:**\n\n* Working on the reconciliation of accounting/finance data between the application platform and the accounting software (Netsuite).\n* Performing regular data analysis using SQL.\n* Running data correction scripts both via SQL and Node js or Python utilities.\n* Gaining a deep understanding of our international financial transactions and inventory movement, including tax, FX, and returns.\n* Supporting finance by investigating and resolving discrepancies in financial transactions, and working cross-functionally to ensure root causes are identified and resolved.\n* Working closely with department heads to understand workflow requirements and identify opportunities for digitization and automation.\n* Provide training and support to team members on new systems and dashboards.\n\n\n\n\n **Requirements:**\n\n* Minimum 3 years of experience required\n* Experience working in the finance/accounting domain.\n* Should be proficient with writing manual queries using SQL to store and manage data related to accounting, bookkeeping, and user analytics.\n* Should have good analytical skills when it comes to data, and should have the ability to write complex queries involving joins to pull the right data.\n* Excellent communication skills.\n \n\t+ Should be able to understand and explain complex logic effectively to people who are not necessarily subject matter experts.\n\t+ Should be clear and concise in English verbal and written communication.\n* Bachelor's degree in Computer Science, Data Science, Information Technology, or related field.\n* Proven experience in data analysis.\n* Excellent analytical skills with the ability to interpret data and translate it into actionable insights.\n* Detail-oriented with a problem-solving mindset.\n* Ability to work independently and collaboratively in a team environment.\n* Some experience with NodeJS or Python would be a plus.\n* Experience in working with Netsuite is a huge plus.\n\n\n\n **We offer**\n\n\n* Dynamic working environment in an extremely fast-growing company\n* Intellectually challenging work, play a massive role in Nivoda’s success and scalability\n* Connect with peers globally in a true no central location team\n* Collaborative and supportive work environment with very little hierarchy\n* Flexible working hours\n\n\n\n\nReport job",
    "Data Engineer\n=============\n\nBusiness Training CentreRemote₹15,00,000 - ₹22,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹15,00,000 - ₹22,00,000 a year\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Night shift\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n**We are Hiring DATA Engineer**\n\n\n* **Type: Full Time**\n* **Location: Navi Mumbai (Remote)**\n* **Shift Timings: 2 General Shift / 1 Night Shift IST**\n* **Experience: 5-12 Years**\n* **Notice Period: Upto 15 Days**\n* **Industry Background: Information Technology, IT**\n* **Educational Qualifications: NA**\n\n\n**Must Have:**\n\n\n* Snowflake, DBT, Data Modelling, Data Warehousing, Data Security, Version Control, SQL, ETL\n\n\n**Good to Have**\n\n\n* AWS\n* Scripting Language\n\n\n**Skills Required**\n\n\n* Snowflake Data\n* Warehousing Data\n* Modelling Data\n* Security SQLETL Version\n* Control DBT\n\n\n**Interview Process**\n\n\n* Screening Round\n* HR Round\n* Two Technical Rounds\n\n\n**Mandatory**\n\n\n* Candidates serving Notice period and not more than 30 days apply.\n* Along with the resumes, please share the Aadhar card and PAN card.\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹1,500,000.00 - ₹2,200,000.00 per year\n\n\nSchedule:\n\n\n* Day shift\n\n\nExperience:\n\n\n* Data Engineer: 5 years (Preferred)\n* Data modeling: 5 years (Preferred)\n* Data warehouse: 5 years (Preferred)\n* Data Security: 5 years (Preferred)\n* AWS: 5 years (Preferred)\n* Version control systems: 5 years (Preferred)\n\n\nWork Location: Remote\n\nReport job",
    "Marketing Data Analyst - IT/ Tech\n=================================\n\nDoit Security, Inc.Remote₹650 - ₹800 an hourApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹650 - ₹800 an hour\n### Job type\n\n* Part-time\n* Temporary\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n**Company Description** \n\n\nDOIT Security stands at the forefront of cloud security innovation in the burgeoning SASE category. We take pride in our excellence in reinforcing cyber defenses, mitigating data exfiltration risks, and driving cost efficiency through operational optimization. Our mission is not only to secure but also to enhance the enterprise user experience by integrating strategic services for greater infrastructure efficiency and innovation.\n\n\n**Role Description** \n\n\nWe are seeking an experienced and highly skilled Marketing Data Analyst to join our dynamic marketing team. The ideal candidate will have a strong analytical background and be proficient in turning complex data into actionable insights to drive our marketing strategies.\n\n\n**Responsibilities** \n\n\n* Collect, analyze, and interpret data from various marketing channels, including digital, social media, email, and traditional advertising.\n* Develop and maintain marketing dashboards and reports to track campaign performance, KPIs, and ROI.\n* Conduct market research to identify trends, competitive analysis, and customer insights.\n* Collaborate with marketing and sales teams to understand business objectives and provide data-driven recommendations.\n* Perform A/B testing and analyze results to optimize marketing campaigns.\n\n\nUtilize statistical methods and data visualization tools to present findings in a clear and actionable manner.\n\n\n* Monitor and report on key metrics such as customer acquisition, conversion rates, and customer lifetime value.\n* Stay up-to-date with industry trends and emerging analytics technologies.\n\n\n**Qualifications** \n\n\n* Bachelor’s degree in Marketing, Statistics, Data Science, or a related field.\n* Proven experience as a Marketing Data Analyst or in a similar role.\n* Proficiency in data analysis tools such as SQL, R, Python, and Excel.\n* Experience with data visualization tools like Tableau, Power BI, or similar.\n* Strong analytical and problem-solving skills with a keen attention to detail.\n* Excellent communication skills and the ability to translate complex data into actionable insights.\n* Knowledge of digital marketing channels and metrics.\n* Experience with web analytics tools (e.g., Google Analytics).\n\n\n**Supplementary Data** \n\n\n* We uphold the highest standards of confidentiality in compliance with EEO guidelines.\n\n\n**What You Can Expect from Us** \n\n\n* Exposure to cutting-edge technologies and architecture.\n* A stimulating, collegial, and fun working environment.\n* Opportunities for professional development and career progression.\n\n\n**Why DOIT Security?** \n\n\nPeople that succeed at DOIT Security are intelligent, driven, and committed to our core principles. Consider the following question:\n\n\n* Do you wish to collaborate with the greatest talent in the industry?\n* Do you want to be a part of the development of disruptive technologies?\n* Do you thrive in a fast-paced, changing environment?\n* Do you value a workplace culture that encourages both individual and group success and recognizes and celebrates success?\n\n\nIf you answered yes, we would be delighted to speak with you about being a member of our award-winning team.\n\n\nDOIT Security is an equal-opportunity workplace committed to diversity. We value and celebrate diversity, and we provide an inclusive atmosphere for all our employees and customers.\n\n\nJob Type: Part-time\n\n\nPay: ₹650.00 - ₹800.00 per hour\n\n\nExperience:\n\n\n* Marketing Data Analytics: 4 years (Required)\n\n\nWork Location: Remote\n\n\nApplication Deadline: 20/05/2024\n\nReport job",
    "Azure Data Engineer\n===================\n\nMyWaysRemote₹10,00,000 - ₹15,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹10,00,000 - ₹15,00,000 a year\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Fixed shift\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n**Key Responsibilities:**\n\n\n* **Data Architecture and Design:**\n* Design and implement scalable and reliable data architectures using Azure services.\n* Develop and maintain ETL (Extract, Transform, Load) pipelines to process and integrate data from various sources.\n* Ensure data solutions are designed for optimal storage, retrieval, and processing efficiency.\n* **Data Integration and Management:**\n* Implement data integration solutions using Azure Data Factory, Azure Databricks, and other relevant tools.\n* Manage and maintain data warehouses and data lakes on Azure.\n* Monitor and optimize data pipelines for performance and cost efficiency.\n* **Data Security and Compliance:**\n* Ensure data solutions comply with relevant data protection regulations and best practices.\n* Implement robust data security measures to safeguard sensitive information.\n* Conduct regular audits and assessments to ensure data integrity and security.\n* **Collaboration and Support:**\n* Work closely with data scientists, business analysts, and other stakeholders to understand data requirements and deliver solutions.\n* Provide technical support and troubleshooting for data-related issues.\n* Train and mentor junior data engineers and other team members on Azure data services and best practices.\n* **Continuous Improvement:**\n* Stay updated with the latest trends and advancements in Azure data services and related technologies.\n* Continuously evaluate and improve existing data solutions and processes.\n* Contribute to the development of best practices and standards for data engineering within the organization.\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹1,000,000.00 - ₹1,500,000.00 per year\n\n\nSchedule:\n\n\n* Fixed shift\n* Monday to Friday\n\n\nExperience:\n\n\n* total work: 3 years (Required)\n\n\nWork Location: Remote\n\nReport job",
    "Cyber Security Data Loss Protection - Forcepoint DLP\n====================================================\n\nVarchai Pvt LtdRemote₹96,112.53 - ₹1,15,748.42 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹96,112.53 - ₹1,15,748.42 a year\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Day shift\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n* Forcepoint DLP · Symantec dlp\n* Forcepoint · Microsoft Purview · Jira · Sumo Logic · Netskope CASB\n* Data Loss Prevention l Security Investigation l Incident Management\n* Team Management · Data loss prevention · Symantec dlp · McAfee · Microsoft Purview · wiretap · Incident Management · compliance handling\n* Data loss prevention\n\n\nJob Type: Full-time\n\n\nPay: ₹96,112.53 - ₹115,748.42 per year\n\n\nSchedule:\n\n\n* Day shift\n* Monday to Friday\n\n\nExperience:\n\n\n* total work: 4 years (Preferred)\n\n\nWork Location: Remote\n\n\nApplication Deadline: 27/05/2024  \nExpected Start Date: 27/05/2024\n\nReport job",
    "Lead Data Engineer\n==================\n\nMobile Programming LLCRemote₹5,00,000 - ₹16,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹5,00,000 - ₹16,00,000 a year\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Health insurance\n* Work from home\n&nbsp;Full job description\n--------------------\n\nData\\_Engineer (6+ Years Experience)\n\n\n#Location: Hyderabad / Remote\n\n\nType: #Immediate Joiners Only\n\n\nWe are seeking a skilled #Data\\_Engineer with expertise in SQL, Python, Spark, Hadoop, and HDFS to join our innovative team!\n\n\n#Key Responsibilities:\n\n\nDevelop and maintain scalable data pipelinesCollaborate with teams for robust data solutionsOptimize data processes for performance\n\n\n#Requirements:\n\n\n6+ years of Data Engineering experience\n\n\nProficiency in SQL, Python, Spark, Hadoop, and HDFS\n\n\nStrong problem-solving skills\n\n\nTeam player with attention to details\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹500,000.00 - ₹1,600,000.00 per year\n\n\nBenefits:\n\n\n* Health insurance\n* Work from home\n\n\nSchedule:\n\n\n* Monday to Friday\n\n\nSupplemental pay types:\n\n\n* Performance bonus\n\n\nExperience:\n\n\n* total work: 6 years (Required)\n* data engineer: 4 years (Required)\n* Hadoop: 3 years (Preferred)\n* Python: 3 years (Required)\n\n\nWork Location: Remote\n\nReport job",
    "Senior Data Engineer\n====================\n\nMobile Programming India Pvt LtdRemote₹5,00,000 - ₹14,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹5,00,000 - ₹14,00,000 a year\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Morning shift\n* Day shift\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Health insurance\n* Provident Fund\n&nbsp;Full job description\n--------------------\n\n**Job Description:- Big Data Engineer:**  \n**Exp: 6+ years**\n\n\n**Skill Set:**\n\n\n**Lead Data Engineer with On-Premises Experience (SQL, Python/Scala, Spark, Hadoop, Hive, HDFS)**\n\n\nThese are the must skill to work/enhance and support existing tools and frameworks and to do day-to-day data-engineering projects.\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹500,000.00 - ₹1,400,000.00 per year\n\n\nBenefits:\n\n\n* Health insurance\n* Provident Fund\n\n\nSchedule:\n\n\n* Day shift\n* Monday to Friday\n* Morning shift\n\n\nSupplemental pay types:\n\n\n* Joining bonus\n* Performance bonus\n* Yearly bonus\n\n\nExperience:\n\n\n* Python: 4 years (Required)\n* Big data: 6 years (Required)\n* Apache Hive: 4 years (Preferred)\n* Spark: 4 years (Preferred)\n* SQL: 4 years (Preferred)\n* Hadoop: 4 years (Required)\n\n\nWork Location: Remote\n\nReport job",
    "Oracle Data Integrator\n======================\n\nGlobal EmployeesRemote₹15,00,000 - ₹30,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹15,00,000 - ₹30,00,000 a year\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Flexible schedule\n&nbsp;Full job description\n--------------------\n\n* Hands-on 6+ year exp in designing complex ODI Oracle Data Integrator packages, ODI Scenarios, Mappings, Variables.\n* Strong exp in in Analysis, Design, Development, Implementation of Data Warehousing in ETL process using ODI 12c/11g.\n* Expertise in Data warehousing, Fact Tables, Dimension Tables, Star and Snowflake Schema modeling.\n\n\n**Job Responsibilities**\n\n\n* Ability to design data quality and reconciliation framework using ODI Integrate ODI with multiple Sources /Target\n* Experience in building/customizing ETLs from Source Systems such as Oracle Database to Data Warehouse.\n* Exp in Working with ODI Designing, Topology Management, Operator, Security management.\n* Exp Oracle Data Integrator Designer (ODI) to develop processes for Extracting, Transforming, Integrating, and loading data into Target Systems.\n* Expertise in configuring the ODI Master and Work Repositories, ODI models etc\n* Excellent in writing PL-SQL DDL & DML queries and troubleshooting complex stored-procedures\n* Packaging components, database operations like Aggregate pivot, union, etc. using ODI mappings, error handling, automation using ODI, Loadplans, Migration of Objects.\n* Must be well-versed and hands-on in using and customizing Knowledge Modules (KM).\n* Setting up topology, building objects in Designer, Monitoring Operator, different types of KMs, Agents, etc.\n* Worked with Oracle, XML data, File in ODI.\n\n\nJob Type: Full-time\n\n\nPay: ₹1,500,000.00 - ₹3,000,000.00 per year\n\n\nBenefits:\n\n\n* Flexible schedule\n\n\nSchedule:\n\n\n* Day shift\n\n\nExperience:\n\n\n* total work: 6 years (Required)\n* Oracle: 6 years (Preferred)\n\n\nWork Location: Remote\n\nReport job",
    "Digital Marketing Specialist\n============================\n\nUltracuresRemote₹10,000 - ₹20,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹10,000 - ₹20,000 a month\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Internet reimbursement\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**Key Responsibilities:**\n\n\n* Develop and execute digital marketing campaigns across various channels, including SEO/SEM, email, social media, and display advertising.\n* Plan and manage our social media platforms.\n* Identify trends and insights, and optimize spend and performance based on the insights.\n* Brainstorm new and creative growth strategies.\n* Plan, execute, and measure experiments and conversion tests.\n* Collaborate with internal teams to create landing pages and optimize user experience.\n* Utilize strong analytical ability to evaluate end-to-end customer experience across multiple channels and customer touchpoints.\n* Instrument conversion points and optimize user funnels.\n* Evaluate emerging technologies. Provide thought leadership and perspective for adoption where appropriate.\n\n\n**Qualifications:**\n\n\n* Bachelor’s degree in marketing, communications, or a related field.\n* Proven working experience in digital marketing.\n* Demonstrable experience leading and managing SEO/SEM, marketing database, email, social media, and/or display advertising campaigns.\n* Highly creative with experience in identifying target audiences and devising digital campaigns that engage, inform, and motivate.\n* Experience in optimizing landing pages and user funnels.\n* Solid knowledge of website analytics tools (e.g., Google Analytics, NetInsight, Omniture, WebTrends).\n* Working knowledge of ad serving tools (e.g., DART, Atlas).\n* Experience in setting up and optimizing PPC campaigns on all major search engines.\n* Strong analytical skills and data-driven thinking.\n* Up-to-date with the latest trends and best practices in online marketing and measurement.\n\n\n**Preferred Skills:**\n\n\n* Knowledge of HTML, CSS, and JavaScript development and constraints.\n* Experience with A/B and multivariate experiments.\n* Familiarity with marketing automation tools (e.g., HubSpot, Marketo, Pardot).\n* Experience with inbound marketing strategies.\n* Strong project management skills.\n\n\n**What We Offer:**\n\n\n* Competitive salary and benefits package.\n* Opportunity to work with a passionate and dedicated team.\n* Professional development and growth opportunities.\n* A dynamic and supportive work environment.\n\n\nJob Type: Full-time\n\n\nPay: ₹10,000.00 - ₹20,000.00 per month\n\n\nBenefits:\n\n\n* Internet reimbursement\n* Work from home\n\n\nSchedule:\n\n\n* Day shift\n\n\nEducation:\n\n\n* Bachelor's (Preferred)\n\n\nExperience:\n\n\n* Digital marketing: 1 year (Preferred)\n* total work: 1 year (Preferred)\n\n\nWork Location: Remote\n\n\nExpected Start Date: 25/05/2024\n\nReport job",
    "Data Analyst Intern\n===================\n\nGlobalShalaRemote₹3,000 - ₹5,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹3,000 - ₹5,000 a month\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Work from home\n&nbsp;Full job description\n--------------------\n\n**Overview**\n\n\nAs the Data Analyst Team Lead, you will play a pivotal role in leading a team of data analysts to extract insights from complex datasets, drive data-driven decision-making processes, and contribute to the overall strategic objectives of our team. Your expertise in data analysis, team management, and communication will be essential in ensuring the success of the team and Excelerate as a whole.\n\n\n**TASK**\n\n\nAs part of this stage, we would like to assign you a task to complete. The details of the task are as follows:\n\n\n**Task 1:** Design a Leaderboard for the TeamObjective: Create a leaderboard that displays the performance of team members based on key performance indicators (KPIs).Task Description:Define KPIs: Determine the key performance indicators (e.g., sales numbers, customer feedback scores, project completion rates) that will be used to measure performance.Data Collection: What is the necessary data for each team member over a specific period (e.g., monthly, quarterly).Design the Leaderboard:Layout: Decide on the structure (e.g., top performers at the top, different sections for different KPIs).Visualization: Choose how to represent the data (e.g., bar graphs, ranks, percentages).Update Frequency: Determine how often the leaderboard will be updated.Tools and Technology: Select the tools or software for creating the leaderboard (e.g., Excel, Google Sheets, specialized leaderboard software).Deliverables:\\* A document detailing the KPIs and data collection methods.\\* A visual prototype of the leaderboard.\n\n\n**Task 2**: Create a Dashboard from Shared DataObjective: Develop a dashboard that visualizes and summarizes the shared data for quick insights and decision-making.Task Description:Understand the Data: Review the data provided to understand its structure, key metrics, and any relevant trends.Define Objectives: Determine what insights or information the dashboard should provide (e.g: trends, performance, etc).Select Metrics: Choose the most important metrics to be displayed on the dashboard.Design the Dashboard:Layout: Plan the dashboard layout, ensuring it is user-friendly and logically organized.Charts and Graphs: Select the appropriate types of charts and graphs to represent the data (e.g., line charts for trends, pie charts for distribution).Filters and Interactivity: Decide on any filters or interactive elements that will allow users to explore the data further.Tools and Technology: Choose the tools or software for creating the dashboard.Deliverables:\\* A document outlining the key metrics and objectives of the dashboard.\\* A visual prototype of the dashboard.\n\n\n**Note:- Please ensure that the completed task is submitted within 24 hours at hr@globalshala.com. Your response to this task will play a crucial role in our final selection decision.Should you have any questions or require further clarification, please do not hesitate to reach out.We look forward to receiving your completed task.**\n\n\nJob Type: Full-time\n\n\nPay: ₹3,000.00 - ₹5,000.00 per month\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Monday to Friday\n\n\nSupplemental pay types:\n\n\n* Performance bonus\n\n\nWork Location: Remote\n\nReport job",
    "CRM & Data Specialist (Financial Services)\n==========================================\n\nVaR Value Research & Media GmbHRemoteJob details\n-----------\n\nHere’s how the job details align with your profile.### Job type\n\n* Full-time\n### Shift and schedule\n\n* Monday to Friday\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Flexible schedule\n* Work from home\n&nbsp;Full job description\n--------------------\n\nVaR Value Research & Media is an international financial publishing company. Our mission is to provide international investors with useful and valuable information to help them make better investment decisions.\n\n\nOur products include our investment platforms AsiaFundManagers.com and Capitalmarkets.net.\n\n\nVaR has its headquarters in Germany. As an international house, we employ staff worldwide.\n\n\nWe are looking for a **CRM & Data Specialist** to join our team as a contractor. We are all working remotely - so will you!\n\n\n**Your background and qualities**\n\n\n* 2-3 years of relevant experience and training as a CRM and data specialist\n* Background in financial services (e.g. working for a bank, insurance company, wealth manager, degree in finance) AND /OR understanding of capital markets and its participants is a must\n* Experience in handling database-based software/CRM systems (e.g. Pipedrive)\n* Savvy Excel skills\n* Knowledge of secondary research\n* Pay strict attention to detail\n* Experience with LinkedIn sales navigator is desirable\n* Independent and reliable way of working\n* Willingness to learn about new topics, fields of work and tools\n* Ability to work within a remote team and follow the instructions of senior management\n* Fluent in English, spoken and written\n\n\n**Your role**\n\n\nAs CRM & Data Specialist you will work closely with the Head of Sales to update, maintain and grow our CRM system and related databases.\n\n\n**Your tasks include**\n\n\n* Take over responsibility for the quality and growth of our customer database\n* Research, build, grow and maintain the database / CRM system\n* Data scraping, data enrichment, data entry\n* Data gathering and web research\n* Analyse investor preferences and behaviour\n* LinkedIn and B2B lead generation; contact list building\n* Email prospecting\n\n\n**What we offer**\n\n\n* Remote/Homeoffice\n* Flexible working hours (Overlap with GMT)\n* An interesting and diversified job in a digital company\n* Working in a committed, international team\n* Be a team member in a future-oriented company with great growth potential\n* A lot of learning opportunities\n* Healthy remote work culture with team activities, such as team brunch, active breaks, …\n\n\nWe look forward to receiving your application!\n\n\nJob Type: Full-time\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Monday to Friday\n\n\nApplication Question(s):\n\n\n* Which CRM system have you worked with so far?\n* What are your salary expectations?\n* When could you join?\n\n\nWork Location: Remote\n\nApply nowsave-icon&nbsp;Report job",
    "Associate Data Scientist\n========================\n\nAscendeumRemoteFrom ₹3,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* From ₹3,00,000 a year\n### Job type\n\n* Full-time\n### Shift and schedule\n\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Health insurance\n* Provident Fund\n* Work from home\n&nbsp;Full job description\n--------------------\n\nKey Responsibilities:  \n● Identify valuable data sources and automate collection processes.  \n● Undertake preprocessing of structured and unstructured data.  \n● Analyze large amounts of information to discover trends and patterns.  \n● Helping develop reports and analysis.  \n● Present information using data visualization techniques.  \n● Assessing tests and implementing new or upgraded software and assisting with strategic  \ndecisions on new systems.  \n● Evaluating changes and updates to source production systems.  \n● Develop, implement, and maintain leading-edge analytic systems, taking complicated  \nproblems and building simple frameworks.  \n● Providing technical expertise in data storage structures, data mining, and data cleansing.  \n● Propose solutions and strategies to business challenges.\n\n\nRequirements:  \n● At least 1 year of experience in Data Analysis.  \n● Complete understanding of Operations Research, Data Modelling, ML, and AI concepts.  \n● Knowledge of Python is mandatory, familiarity with MySQL, SQL, Scala, Java or C++ is  \nan asset.  \n● Experience using visualization tools (e.g. Jupyter Notebook) and data frameworks  \n(e.g.Hadoop).  \n● Analytical mind and business acumen.  \n● Strong math skills (e.g. statistics, algebra).  \n● Problem-solving aptitude  \n● Excellent communication and presentation skills.  \n● Bachelor’s / Master's Degree in Computer Science, Engineering, Data Science or other  \nquantitative or relevant field is preferred.  \nThank you for your interest in joining Ascendeum.\n\n\nJob Type: Full-time\n\n\nPay: From ₹300,000.00 per year\n\n\nBenefits:\n\n\n* Health insurance\n* Provident Fund\n* Work from home\n\n\nSchedule:\n\n\n* Day shift\n\n\nSupplemental pay types:\n\n\n* Performance bonus\n\n\nApplication Question(s):\n\n\n* What is your notice period?\n* Kindly mention your CCTC and ECTC?\n* Mention your Linkedin URL\n\n\nExperience:\n\n\n* Data science: 1 year (Preferred)\n\n\nWork Location: Remote\n\n\nApplication Deadline: 26/05/2024\n\nReport job",
    "Power BI Developer\n==================\n\nAlbireo Tech SystemRemote₹28,000 a monthApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹28,000 a month\n### Job type\n\n* Part-time\n* Temporary\n* Freelance\n### Shift and schedule\n\n* Morning shift\n* Night shift\n* Evening shift\n* US shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Work from home\n&nbsp;Full job description\n--------------------\n\nWe are looking for the candidate having more than 5 years of experience in below technologies , fixed in the project for long term\n\n\nSkills - SharePoint, powerapps, Power automate, python sage intact, Power BI, Python, Rest API, PostgreSQL, chat bot development\n\n\nTiming : 8 AM\n\n\nDuration : 3 hrs\n\n\nWork type -remote work over the zoom call\n\n\nJob Types: Part-time, Freelance  \nContract length: 6 months\n\n\nPay: ₹28,000.00 per month\n\n\nExpected hours: 5 per week\n\n\nBenefits:\n\n\n* Work from home\n\n\nSchedule:\n\n\n* Evening shift\n* Morning shift\n* US shift\n\n\nSupplemental pay types:\n\n\n* Overtime pay\n\n\nEducation:\n\n\n* Bachelor's (Preferred)\n\n\nExperience:\n\n\n* Power BI: 5 years (Required)\n* python sage intact,: 5 years (Required)\n* Rest API: 5 years (Required)\n* chat bot: 5 years (Required)\n* Power automate: 5 years (Required)\n\n\nShift availability:\n\n\n* Night Shift (Preferred)\n\n\nWork Location: Remote\n\nReport job",
    "Senior Data Engineer\n====================\n\nShrenzo careers Pvt LtdRemoteUp to ₹20,00,000 a yearApply nowsave-icon&nbsp;Job details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* Up to ₹20,00,000 a year\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Rotational shift\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Health insurance\n* Paid sick time\n* Provident Fund\n* Work from home\n&nbsp;Full job description\n--------------------\n\n* Senior Developer – 7 to 8 years exp – 1 Position\n* Developer – 3 to 5 years exp – 2 Position\n\n\n**Work Type:** Contract – 6 months.\n\n\n**Mode of Work:** Remote/WFO.\n\n\n**Job Description :**\n\n\nWe are seeking a highly skilled and experienced Data Engineer with expertise in data development in AWS and Oracle. The ideal candidate will have a minimum of 5 years of experience in data engineering, with a strong focus on AWS and Oracle technologies. The Data Engineer will be responsible for designing, developing, and maintaining data solutions that meet the organization's data needs.\n\n\nResponsibilities:\n\n\n- Design, develop, and implement data solutions using AWS and Oracle technologies.\n\n\n- Collaborate with cross-functional teams to gather requirements and define data engineering solutions.\n\n\n- Develop and maintain data pipelines and data integration workflows.\n\n\n- Optimize and tune data solutions for performance and scalability.\n\n\n- Ensure data quality and integrity through data validation and cleansing processes.\n\n\n- Monitor and troubleshoot data engineering processes to identify and resolve issues.\n\n\nRequirements:\n\n\n- Bachelor’s degree in computer science, Engineering, or a related field.\n\n\n- Minimum of 5 years of experience in data engineering, with a focus on AWS and Oracle technologies.\n\n\n- Strong expertise in AWS services such as S3, Redshift, Glue, Athena, and EMR.\n\n\n- Proficiency in Oracle database technologies, including SQL, PL/SQL, and Oracle Data Integrator (ODI).\n\n\n- Experience with data modeling, data warehousing, and data governance principles.\n\n\n- Strong problem-solving and analytical skills.\n\n\n- Excellent communication and collaboration skills.\n\n\nJob Types: Full-time, Permanent\n\n\nPay: Up to ₹2,000,000.00 per year\n\n\nBenefits:\n\n\n* Health insurance\n* Paid sick time\n* Provident Fund\n* Work from home\n\n\nSchedule:\n\n\n* Day shift\n* Rotational shift\n\n\nSupplemental pay types:\n\n\n* Performance bonus\n* Yearly bonus\n\n\nExperience:\n\n\n* S3: 5 years (Preferred)\n* Redshift: 5 years (Preferred)\n* Glue: 5 years (Preferred)\n* EMR: 5 years (Preferred)\n* SQL: 5 years (Preferred)\n* PL/SQL: 5 years (Preferred)\n* Oracle Data Integrator: 4 years (Preferred)\n* Data Engineer: 5 years (Preferred)\n* AWS: 5 years (Preferred)\n* Oracle: 5 years (Preferred)\n\n\nWork Location: Remote\n\nReport job",
    "Marketing & Sales Data Analyst (Remote - India)\n===============================================\n\nNivodaRemoteLocation\n--------\n\nRemote&nbsp;BenefitsPulled from the full job description\n--------------------------------------------\n\n* Paid time off\n&nbsp;Full job description\n--------------------\n\n\n\n\n\n As the Marketing & Sales Analyst, your mission is to be the driving force behind our business success. You will harness the power of data and analytics to uncover valuable insights, fuel strategic decision-making, and propel our organisation towards sustainable growth. Your keen eye for detail and analytical prowess will empower us to optimise marketing and sales performance, seize market opportunities, and stay one step ahead of the competition. With your expertise, we will navigate complex business landscapes, refine our strategies, and unlock untapped potential.\n   \n\n  \n Together, we will forge new paths, make informed decisions, and achieve unparalleled success in a rapidly evolving marketplace. Join us on this exciting journey and be instrumental in shaping our future as a leader in the industry.\n   \n\n  \n **About us:**\n  \n\n  \n Nivoda is a young and energetic global team headquartered in London with offices in Mumbai, New York, Hong Kong, Johannesburg, Antwerp and Amsterdam.\n   \n\n  \n We are an extremely fast-growing B2B marketplace changing how the global jewelry industry operates. We connect buyers and sellers of jewelry on our online platform and facilitate the most transparent, efficient and cost-effective way for the jewelry industry to sell and buy jewelry.\n   \n\n  \n Nivoda has a rapidly growing workforce expanding into new countries with a dynamic, supportive and collaborative culture.\n   \n\n  \n The company's sales have grown over 250% in the last 12 months, and the team has grown from 30 to over 400 internationally. We are a global team who can always be trusted, driven to make big and bold moves to transform a traditional industry.To know more please visit www.nivoda.net\n   \n\n  \n **What you’ll do:**\n\n  \n\n\n* Forecasting: Support the marketing and sales team on forecasting activity and reporting on both departments trend to forecasts on a monthly basis\n* Funnel Optimisation: Analyse the marketing and sales funnel, lead generation and conversion rates to sales\n* Attribution: Analyse the uplift generated by marketing to sales activity and effectively attribute sales credit to each piece of the funnel\n* Data Visualisation: Own and maintain sales and marketing dashboards\n* Customer segmentation: Analyse customer and financial data to identify cohorts that present key business opportunities for sales and marketing\n* Measurement: Support team in establishing clear measurement plans for testing and report out on test results\n\n\n\n **What you’ll need :**\n\n  \n\n\n* 6-9 years of marketing & sales analytics experience\n* Proficiency in analysing complex datasets, extracting meaningful insights, and identifying patterns, trends and opportunities using statistical techniques and tools such as Excel, SQL, or data visualisation software.\n* Ability to analyse financial data, including revenue, costs, and profitability, and perform financial modelling and forecasting to support commercial decision-making.\n* Understanding of marketing channels, their tracking and reporting and potential impact to a business.\n* Strong proficiency in Microsoft Excel, including advanced formulas, pivot tables, data manipulation, and analysis. Familiarity with other analytics tools such as Python, R, or MATLAB can be an added advantage.\n* Ability to create accurate sales & marketing forecasts considering historical data, market trends, and seasonality.\n* Clear understanding and experience working on cross-channel attribution models. Bonus points if you have experience developing custom models\n\n\n\n **What we offer :**\n\n  \n\n\n* Dynamic working environment in a extremely fast growing company\n* Ample opportunity to grow and learn\n* Work in an international environment\n* Potential to grow into managerial role\n* Hybrid working environment\n* Flexible working\n* Unlimited paid leaves\n* Fast-paced and global working environment\n\n\n\n\nYou must create an Indeed account before continuing to the company website to applyApply nowsave-icon&nbsp;Report job",
    "Data Engineer - 8+yrs\\_Chennai Location\n=======================================\n\nGame Changer IT ServicesRemoteUp to ₹25,00,000 a yearJob details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* Up to ₹25,00,000 a year\n### Job type\n\n* Full-time\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n**Data Engineer**\n\n\n**Azure Dev Ops + ADF + Synapse + Databricks, SQL**\n\n\n**8+years of Experience** \n\n\n**Location - Chennai**\n\n\nMinimum Education and Experience\n\n\n● Bachelor’s degree or Master’s degree in Computer Science, IT, or other relevant areas\n\n\n● Bachelor’s degree or Master degree with 12+ years related experience\n\n\nRequired Skills\n\n\n● Azure Services Knowledge: In-depth understanding and hands-on experience with key Azure services relevant to BI, such as Azure Synapse Analytics (formerly Azure SQL Data Warehouse), Azure Data Factory, Azure Databricks, Azure Analysis Services, Azure Data Lake Storage, and Azure SQL Database.\n\n\n● Data Integration: Proficiency in using Azure Data Factory for data integration tasks, including data ingestion, transformation, and orchestration of ETL (Extract, Transform, Load) processes.\n\n\n● Data Modeling: Experience in designing and implementing data models using Azure Analysis Services or other similar technologies to create scalable and performant BI solutions.\n\n\n● Data Visualization: Knowledge of data visualization tools such as Power BI, including experience in building interactive dashboards, reports, and data visualizations to enable data-driven decision-making.\n\n\n● Performance Optimization: Ability to optimize BI solutions for performance and scalability, including tuning SQL queries, optimizing data loading processes, and leveraging Azure's built-in optimization features.\n\n\n● Security and Compliance: Understanding of Azure's security and compliance capabilities, including role-based access control (RBAC), data encryption, and compliance certifications (e.g., GDPR, HIPAA, etc.) relevant to BI solutions.\n\n\n● Cloud Architecture: Familiarity with cloud architecture principles and best practices, including knowledge of Azure architecture patterns, resource management, and cost optimization techniques.\n\n\n● Monitoring and Management: Experience in monitoring and managing Azure BI solutions using Azure Monitor, Azure Log Analytics, and other monitoring tools to ensure system reliability, performance, and availability.\n\n\n● Collaboration and Communication: Strong collaboration and communication skills to work effectively with cross-functional teams, stakeholders, and business users to understand requirements, translate them into technical solutions, and drive successful BI implementations.\n\n\nJob Type: Full-time\n\n\nPay: Up to ₹2,500,000.00 per year\n\n\nWork Location: Remote\n\nApply nowsave-icon&nbsp;Report job",
    "Sr Clin Data Assoc\n==================\n\nThermo Fisher Scientific3.4 out of 5RemoteThermo Fisher Scientific\n------------------------\n\n4,960 reviewsRead what people are saying about working here.Job details\n-----------\n\nHere’s how the job details align with your profile.### Job type\n\n* Full-time\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n\n**Job Description**\n\n\n\n **Summarized Purpose:**  \n Performs all aspects of the data cleaning process, with minimal supervision, in accordance with GCP and SOPs/WPDs in order to assess the safety and efficacy of investigational products and/or medical devices.\n\n\n\n **Essential Function:**\n\n\n* Supports the setup of study activities such as database design, testing of data entry screens, and Data Validation Manual (DVM) creation, as required.\n* Reviews data listings for accuracy and consistency of data.\n* Acts as point person and subject matter expert for specialized study-specific processes.\n* Generates, tracks and resolves data clarifications and queries and makes changes to the clinical database as required.\n* Contributes to the improvement of data management processes on a global level.\n* Produces project-specific status reports for management and/or clients on a regular basis.\n* Provides training and work direction to junior staff as required\n\n\n **Knowledge, Skills and Abilities:**\n\n\n* Applies knowledge and skills in a highly organized fashion while adhering to regulatory guidelines, global SOPs and client expectations\n* Strong attention to detail and skill with numbers\n* Good written and verbal communication skills\n* Good analytical/problem-solving skills\n* Ability to maintain a high degree of confidentiality with clinical data and client's proprietary data\n* Strong customer focus and excellent interpersonal skills.\n* Knowledge of medical/clinical terminology\n* Understands project protocol and DVM\n* Proven ability in achieving applicable technical competencies per the DM competency grid\n\n\n\nYou must create an Indeed account before continuing to the company website to applyApply nowsave-icon&nbsp;Report job",
    "Business Analyst\n================\n\nGlobal EmployeesRemote₹10,00,000 - ₹30,00,000 a yearJob details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹10,00,000 - ₹30,00,000 a year\n### Job type\n\n* Permanent\n* Full-time\n### Shift and schedule\n\n* Day shift\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\n* Antier is playing a substantial role in digitization of money and tokenization of Assets, emergence of stable coin, which is disrupting the complete financial eco-system.\n* A whole parallel economy is coming up where secondary market exchanges will be playing a major role in bringing the liquidity in the market viz-a-viz using blockchain technology.\n\n\n**Job Responsibilities**\n\n\n* Assist in the definition of project scope and objectives, involving all relevant stakeholders and ensuring feasibility, capability, and bandwidth\n* Manage changes to the project scope, project schedule, and project costs using appropriate verification techniques\n* Create and maintain comprehensive project documentation\n* Ability to translate intelligence from data into business language with clearly articulating the approach, impacts, and results\n* Understanding of Analytical concepts, tools, and its applications\n* Develop a detailed project plan to monitor and track progress\n* Coordinate within the team and stakeholders for the flawless execution of the project\n* Ensure that all projects are delivered on-time, within scope, and meet the objectives\n* Perform risk management to minimize project risks\n* Ability to multi-task and manage various project elements simultaneously\n* Analyzing existing system documentation to summarize existing system functionality as it relates to the work at hand\n* Supporting the identification of team priorities based upon feedback from the customers, key stakeholders, and the team\n* A good understanding of Agile values, principles, and methodologies with experience of working within an Agile environment\n* User Story creation and Gap Analysis\n* User Acceptance Testing Support\n* Good communication skills, with the ability to communicate complex technical concepts clearly to the stakeholders, your peers, and management level colleagues\n\n\nJob Types: Full-time, Permanent\n\n\nPay: ₹1,000,000.00 - ₹3,000,000.00 per year\n\n\nSchedule:\n\n\n* Day shift\n\n\nExperience:\n\n\n* Agile Scrum: 2 years (Preferred)\n* Business Analyst: 2 years (Preferred)\n* Total work: 2 years (Required)\n\n\nWork Location: Remote\n\nApply nowsave-icon&nbsp;Report job",
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
]
# Out:
# ["Engagement & Data Specialist\n============================\n\nMANAH WellnessRemote₹50,000 - ₹60,000 a monthJob details\n-----------\n\nHere’s how the job details align with your profile.### Pay\n\n* ₹50,000 - ₹60,000 a month\n### Job type\n\n* Full-time\n&nbsp;Location\n--------\n\nRemote&nbsp;Full job description\n--------------------\n\nExperience: 2+ years\n\n\nResponsibilities:\n\n\nMember Categorization and Profiling:\n\n\n* Categorise alliance members by clients, partners, psychology networks, sectors, and geographical locations.\n* Maintain a detailed list of potential members and profile these members.\n\n\nOnboarding:\n\n\n* Manage the onboarding process for new alliance members, including sending emails, special invitations, and providing access to online/offline products.\n\n\nEngagement:\n\n\n* Plan and execute engagement activities such as twice-monthly learning circles.\n* Facilitate learning opportunities, sharing of best practices, and celebration events.\n* Develop
# ...

# %%
#| include: false 

jobs = [dict(job, description=detes[i]) for i, job in enumerate(jobs)]
# Out:
# [{'title': 'Engagement & Data Specialist',
#   'url': 'https://in.indeed.com/rc/clk?jk=285390b95f5eb315&bb=ieAR1gQO9ngB2dZZAT6xG55jhL5vtZnCefV3rOBRqsyV3BUir1rO5pFwuu_K7gYvyR5iWEay6R2FI9HeZdRdDE2mM0RBo7pkgeODQD1ZwjJHE0oQz45kG3PJOAr1oIAA&xkcb=SoAa67M3AavTmWx80x0LbzkdCdPP&fccid=9b477bc92ee08db0&cmp=Capital-Mantra&ti=Engagement+Specialist&vjs=3',
# ...

# %%
#| include: false 

options = pl.DataFrame([options]).drop("location")
# Out:
# shape: (1, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ search_te ┆ search_ra ┆ num_pages ┆ url       ┆ … ┆ Job type  ┆ Location  ┆ Company   ┆ Job      │
# │ rm        ┆ dius      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ Language │
# │ ---       ┆ ---       ┆ i64       ┆ list[str] ┆   ┆ list[str] ┆ list[str] ┆ list[str] ┆ ---      │
# │ str       ┆ i64       ┆           ┆           ┆   ┆           ┆           ┆           ┆ list[str │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ data      ┆ 4         ┆ 3         ┆ ["https:/ ┆ … ┆ ["Full-ti ┆ ["Remote  ┆ ["Nagarro ┆ ["Englis │
# │           ┆           ┆           ┆ /in.indee ┆   ┆ me        ┆ (596)"]   ┆ (47)",    ┆ h        │
# ...

# %%
#| include: false 

options.columns = [x.upper().replace(" ", "_") for x in options.columns]  # normalise column names

# %%
#| include: false 

lastrowid = con.sql(
    "INSERT INTO SEARCHES (SEARCH_TERM, URL, LOCATION, REMOTE, JOB_TYPE, PAY, COMPANY, JOB_LANGUAGE) SELECT SEARCH_TERM, URL, LOCATION, REMOTE, JOB_TYPE, PAY, COMPANY, JOB_LANGUAGE, FROM options RETURNING SEARCH_ID;"
).fetchall()[0][0]
# Out:
# 1

# %%
#| include: false 

jbs = (
    pl.DataFrame(jobs)
    .drop_nulls()
    .with_columns(
        pl.col("description").str.slice(0, pl.col("description").str.find("\n=====")).alias("title"),
        pl.lit(lastrowid).alias("search_id"),  # search_id as retreived from last insert
    )
)
# Out:
# shape: (30, 4)
# ┌────────────────────────┬──────────────────────────────┬──────────────────────────────┬───────────┐
# │ title                  ┆ url                          ┆ description                  ┆ search_id │
# │ ---                    ┆ ---                          ┆ ---                          ┆ ---       │
# │ str                    ┆ str                          ┆ str                          ┆ i32       │
# ╞════════════════════════╪══════════════════════════════╪══════════════════════════════╪═══════════╡
# │ Engagement & Data      ┆ https://in.indeed.com/rc/clk ┆ Engagement & Data Specialist ┆ 1         │
# │ Specialist             ┆ ?j…                          ┆ =…                           ┆           │
# │ Digital Marketing      ┆ https://in.indeed.com/rc/clk ┆ Digital Marketing Specialist ┆ 1         │
# │ Specialist             ┆ ?j…                          ┆ =…                           ┆           │
# ...

# %%
#| include: false 

con.sql(
    "INSERT INTO JOBS (SEARCH_ID, TITLE, URL, DESCRIPTION) SELECT SEARCH_ID, TITLE, URL, DESCRIPTION FROM jbs;"
)

# %% [markdown]
# - List tables in the DB

# %%
con.sql("SHOW TABLES;")
# Out:
# ┌──────────┐
# │   name   │
# │ varchar  │
# ├──────────┤
# │ JOBS     │
# │ SEARCHES │
# └──────────┘

# %% [markdown]
# - The `SEARCHES` table stores the Search sessions.

# %%
con.sql("SELECT * FROM SEARCHES;").pl()
# Out:
# shape: (1, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ SEARCH_ID ┆ SEARCH_TE ┆ URL       ┆ LOCATION  ┆ … ┆ JOB_TYPE  ┆ PAY       ┆ COMPANY   ┆ JOB_LANG │
# │ ---       ┆ RM        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ UAGE     │
# │ i32       ┆ ---       ┆ list[str] ┆ list[str] ┆   ┆ list[str] ┆ list[str] ┆ list[str] ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ list[str │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1         ┆ data      ┆ ["https:/ ┆ ["Remote  ┆ … ┆ ["Full-ti ┆ ["₹ 37,50 ┆ ["Nagarro ┆ ["Englis │
# │           ┆           ┆ /in.indee ┆ (596)"]   ┆   ┆ me        ┆ 0.00+/mon ┆ (47)",    ┆ h        │
# ...

# %% [markdown]
# - `DuckDB` allows us to easily break down and parse this information.

# %%
con.sql("SELECT UNNEST(JOB_TYPE) AS JOB_TYPES FROM SEARCHES WHERE SEARCH_ID=1;")
# Out:
# ┌──────────────────┐
# │    JOB_TYPES     │
# │     varchar      │
# ├──────────────────┤
# │ Full-time (427)  │
# │ Contract (76)    │
# │ Temporary (75)   │
# │ Part-time (37)   │
# │ Internship (11)  │
# │ Fresher (7)      │
# └──────────────────┘

# %% [markdown]
# - The `JOBS` table contains the job details.

# %%
con.sql("SELECT * FROM JOBS LIMIT 5;")
# Out:
# ┌────────┬───────────┬──────────────────────┬──────────────────────┬───────────────────────────────────────────────────┐
# │ JOB_ID │ SEARCH_ID │        TITLE         │         URL          │                    DESCRIPTION                    │
# │ int32  │   int32   │       varchar        │       varchar        │                      varchar                      │
# ├────────┼───────────┼──────────────────────┼──────────────────────┼───────────────────────────────────────────────────┤
# │      1 │         1 │ Engagement & Data …  │ https://in.indeed.…  │ Engagement & Data Specialist\n=================…  │
# │      2 │         1 │ Digital Marketing …  │ https://in.indeed.…  │ Digital Marketing Specialist\n=================…  │
# │      3 │         1 │ Marketing Associate  │ https://in.indeed.…  │ Marketing Associate\n===================\n\nInd…  │
# │      4 │         1 │ Research Analyst (…  │ https://in.indeed.…  │ Research Analyst (WFH Relevant candidates only,…  │
# ...

# %% [markdown]
# - Links (`<a />`) are stripped out from job descriptions for easier usage with other systems, like LLMs, for extracting more granular details.

# %%
from IPython.display import display, Markdown

display(
    Markdown(
        con.sql(
            "SELECT len(DESCRIPTION) DESC_LEN, DESCRIPTION FROM JOBS ORDER BY DESC_LEN LIMIT 1;"
        ).fetchone()[1]
    )
)
# Out:
# Cyber Security Data Loss Protection - Forcepoint DLP
# ...
#
# Varchai Pvt LtdRemote₹96,112.53 - ₹1,15,748.42 a yearApply nowsave-icon&nbsp;Job details
# -----------
#
# Here’s how the job details align with your profile.### Pay
#
# * ₹96,112.53 - ₹1,15,748.42 a year
# ### Job type
#
# * Full-time
# ### Shift and schedule
#
# * Day shift
# * Monday to Friday
# &nbsp;Location
# --------
#
# Remote&nbsp;Full job description
# --------------------
#
# * Forcepoint DLP · Symantec dlp
# * Forcepoint · Microsoft Purview · Jira · Sumo Logic · Netskope CASB
# * Data Loss Prevention l Security Investigation l Incident Management
# * Team Management · Data loss prevention · Symantec dlp · McAfee · Microsoft Purview · wiretap · Incident Management · compliance handling
# * Data loss prevention
#
#
# Job Type: Full-time
#
#
# Pay: ₹96,112.53 - ₹115,748.42 per year
#
#
# Schedule:
#
#
# * Day shift
# * Monday to Friday
#
#
# Experience:
#
#
# * total work: 4 years (Preferred)
#
#
# ...

# %%
# Finally, don't forget to close the connection!

con.close()

# %% [markdown]
# What Next?

# %% [markdown]
# The possibilites are endless!
#
# - Extract specific details from Job descriptions using Natural-language processing tools, or LLMs using Retrieval-augmented Generation techniques.
# - Create an embeddings map of the descriptions to spot patterns.
# - Stay on top of the latest trends in the job markets by monitoring the top keywords in a search session.

# %% [markdown]
# ![Keep Coding](img/keep_coding.webp)\
# Keep Coding!
